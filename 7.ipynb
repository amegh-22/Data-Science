# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
iris = load_iris()
X = iris.data
y = iris.target
fname = iris.feature_names
tname = iris.target_names
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
clf = DecisionTreeClassifier(criterion="entropy", max_depth=4, min_samples_leaf=2)
clf = clf.fit(X_train, y_train)
plt.figure(figsize=(16,10))
plot_tree(
    clf,
    fontsize=12,
    filled=True,
    rounded=True,
    class_names=tname,
    feature_names=fname,
    proportion=True,           
    impurity=True              
)
plt.title("Decision Tree for Iris Dataset", fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
accuracy = clf.score(X_test, y_test)
print("Model accuracy:", round(accuracy * 100, 2), "%")
# Out:
# Model accuracy: 100.0 %

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
from sklearn import metrics
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
iris=pd.read_csv("test1.csv")
print(iris)
X = iris[['sore_throat','fever','swollen_glands','congestion','headache']]

y = iris[['diagnosis']]

fname = ['sore_throat','fever','swollen_glands','congestion','headache']
tname=['Allergy','Cold','Strep_Throat']
clf = DecisionTreeClassifier(criterion="entropy")
clf = clf.fit(X,y)

plt.figure()
tree.plot_tree(clf,fontsize=10,filled=True,rounded=True,class_names=tname,feature_names=fname)
plt.show()
#print(clf.predict(newcase))
# Out:
#    sore_throat  fever  swollen_glands  congestion  headache     diagnosis
# 0            1      1               1           1         1  Strep_Throat
# 1            0      1               0           0         1       Allergy
# 2            0      0               0           1         0          Cold
# 3            1      1               1           0         1  Strep_Throat
# 4            0      0               0           1         1          Cold
# 5            1      0               1           0         0       Allergy
# 6            0      1               0           1         0       Allergy
# 7            1      1               1           1         0  Strep_Throat
# 8            0      0               0           0         1          Cold

# %%
newcase=[[0,0,1,0,0]]
y_new=clf.predict(newcase)
print(y_new)
# Out:
# ['Allergy']
# C:\Users\cacet\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
